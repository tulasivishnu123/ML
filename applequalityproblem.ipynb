# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# Create a sample dataset
X = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])  # Feature data
y = np.array([0, 1, 0, 1])  # Labels

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Print the split sets
print("X_train: ", X_train)
print("X_test: ", X_test)
print("y_train: ", y_train)
print("y_test: ", y_test)
# Out:
# X_train:  [[7 8]
#  [1 2]
#  [5 6]]
# X_test:  [[3 4]]
# y_train:  [1 0 0]
# y_test:  [1]

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import pandas as pd

# Create a sample dataset
text = ['Hello my name is james', 'james this is my python notebook', 'james trying to create a big project']

# Create a CountVectorizer object
vectorizer = CountVectorizer()

# Fit the vectorizer to the text data
vectorizer.fit(text)

# Transform the text data into a matrix of token counts
X = vectorizer.transform(text)

# Print the resulting matrix
print(X)
# Out:
#   (0, 2)	1
#   (0, 3)	1
#   (0, 4)	1
#   (0, 5)	1
#   (0, 6)	1
#   (1, 3)	1
#   (1, 4)	1
#   (1, 5)	1
#   (1, 7)	1
#   (1, 9)	1
#   (1, 10)	1
#   (2, 0)	1
#   (2, 1)	1
#   (2, 4)	1
#   (2, 8)	1
#   (2, 11)	1
#   (2, 12)	1

# %%
import pandas as pd
data=pd.read_csv('applequality.csv')
data
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df=pd.DataFrame(data)
df=df.drop('A_id',axis=1)
df
df=df.drop(4000,axis=0)
df
feature=df[{'Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity'}]
classlabel=df[{'Quality'}]
print(feature)
print(classlabel)
# Out:
#         Weight      Size  Juiciness  Crunchiness  Ripeness  Sweetness  \
# 0    -2.512336 -3.970049   1.844900    -1.012009  0.329840   5.346330
# 1    -2.839257 -1.195217   0.853286     1.588232  0.867530   3.664059
# 2    -1.351282 -0.292024   2.838636    -0.342616 -0.038033  -1.738429
# 3    -2.271627 -0.657196   3.637970    -0.097875 -3.413761   1.324874
# 4    -1.296612  1.364217   3.030874    -0.553006 -1.303849  -0.384658
# ...        ...       ...        ...          ...       ...        ...
# 3995 -1.067408  0.059386   1.697986     0.473052  2.244055  -3.714549
# 3996  1.949253 -0.293118   0.024523    -0.640196 -1.087900  -0.204020
# 3997 -2.138247 -2.634515   2.199709     0.657223  4.763859  -2.440461
# 3998 -1.779337 -4.008004   2.161435    -0.200329  0.214488   2.366397
# 3999 -1.715505  0.278540   1.266677    -1.154075 -0.776571   0.121217
#
#            Acidity
# 0     -0.491590483
# 1     -0.722809367
# 2      2.621636473
# 3      0.790723217
# 4      0.501984036
# ...

# %%
X_train, X_test,Y_tr,Y_te = train_test_split(feature,classlabel,test_size=0.25)
X_train
# Out:
#         Weight      Size  Juiciness  Crunchiness  Ripeness  Sweetness  \
# 2824 -3.437991 -0.740123   2.612485     1.375174 -0.454034   5.079820
# 781  -0.648707  1.081001   0.463345     0.314276 -1.691862   1.237449
# 2974 -0.647456 -1.780332   2.566732     0.190043  0.032295   0.921314
# 2201 -0.472325 -1.448373   2.708222     1.471497  1.332537  -0.284502
# 31   -0.096412 -2.560872   3.271688     1.318294 -1.797185   2.413774
# ...        ...       ...        ...          ...       ...        ...
# 1780 -1.512573 -1.453800   1.300212     0.324360  2.948907  -0.956300
# 165   1.836154 -0.348625  -0.850151     3.549382 -3.651885  -0.191223
# 2569 -1.154856 -1.784265   2.171637    -0.812830  2.529716   1.044179
# 3692  0.054137 -1.953106  -0.707614    -0.052253  0.808005   1.977852
# 2563 -2.170973  2.287517   3.497371     3.136561 -2.396689  -0.931733
#
#            Acidity
# 2824  -2.678681961
# 781    2.524304064
# 2974   2.274141292
# 2201   0.658072598
# 31    -2.636844815
# ...

# %%
X_test
# Out:
#         Weight      Size  Juiciness  Crunchiness  Ripeness  Sweetness  \
# 3717 -4.023888 -0.355936   1.506341     1.119228  2.501914   2.211531
# 3593 -2.088086 -3.233427   0.347460     0.883921  0.941763   2.662541
# 3103  0.375349 -2.822617  -2.198990     3.013857  2.905700  -0.269985
# 2679 -1.314066  0.051800   4.457239    -2.413558 -2.521057   0.371338
# 2647 -2.915323  2.647636   1.538986     0.956051  2.483410  -3.768891
# ...        ...       ...        ...          ...       ...        ...
# 2955  4.099711  0.445244   0.749228    -1.433040 -1.198482  -0.390646
# 2451 -3.484319 -1.066492   0.532620     1.853618  1.661234   4.131262
# 1279 -4.762105  2.139997  -0.337348     0.964478  3.123965   2.830566
# 1421  1.447339  0.299703  -2.035131     1.886963  0.293595  -4.133977
# 906  -1.667305  1.157303  -3.066174     4.061074 -0.020477  -3.933964
#
#            Acidity
# 3717   0.735253371
# 3593  -1.236918712
# 3103  -1.016811874
# 2679   -1.31740779
# 2647  -0.990261265
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train,Y_tr)
y=clf.predict(X_test)
accuracy = clf.score(X_test, Y_te)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
confusionmatrix = confusion_matrix(Y_te, y)
print("Confusion matrix:\n%s" % confusionmatrix)
# Out:
# Confusion matrix:
# [[392  89]
#  [111 408]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plot_tree(clf, filled=True)
plt.show()
